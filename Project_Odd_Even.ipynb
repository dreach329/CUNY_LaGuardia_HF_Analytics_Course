# %%
number = int(input("Enter a number: "))
if number % 2 == 0:
    print("That number is even.")
else:
    print("That number is odd.")
# Out:
# Enter a number:  7
# That number is odd.

# %%
number = int(input("Enter a number: "))
if number % 2 == 0:
    print("That number is even.")
else:
    print("That number is odd.")
# Out:
# Enter a number:  10
# That number is even.

# %%
number = int(input("Enter a number: "))
if number % 2 == 0:
    print("That number is even.")
else:
    print("That number is odd.")
# Out:
# Enter a number:  1026
# That number is even.

# %%
number = int(input("Enter a number: "))
if number % 4 == 0:
    print("This number is a multiple of four!")
else:
    print("This number is NOT multiple of four.")
# Out:
# Enter a number:  44
# This number is a multiple of four!

# %%
number = int(input("Enter a number: "))
if number % 4 == 0:
    print("This number is a multiple of four!")
else:
    print("This number is NOT multiple of four.")
# Out:
# Enter a number:  1267
# This number is NOT multiple of four.

# %%
number = int(input("Enter a number: "))
check = int(input("Enter a number: "))
if number % check == 0:
    print("There is no remainder. This divides evenly.")
else:
    print("There is a remainder.")
# Out:
# Enter a number:  12
# Enter a number:  4
# There is no remainder. This divides evenly.

# %%
number = int(input("Enter a number: "))
check = int(input("Enter a number: "))
if number % check == 0:
    print("There is no remainder. This divides evenly.")
else:
    print("There is a remainder.")
# Out:
# Enter a number:  55
# Enter a number:  3
# There is a remainder.

# %%
number = int(input("Enter a number: "))
check = int(input("Enter a number: "))
if number % check != 0:
    print("There is a remainder.")
else:
    print("There is a no remainder. This divides evenly.")
# Out:
# Enter a number:  1127
# Enter a number:  33
# There is a remainder.
